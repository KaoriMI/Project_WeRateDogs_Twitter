# %%
import numpy as np
import pandas as pd

# %%
pd.options.display.max_colwidth = 100

# %%
import tweepy

consumer_key = 'YOUR CONSUMER KEY'
consumer_secret = 'YOUR CONSUMER SECRET'
access_token = 'YOUR ACCESS TOKEN'
access_secret = 'YOUR ACCESS SECRET'

auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_secret)

api = tweepy.API(auth)

# %%
conda install -c conda-forge tweepy
# Out:
# ^C
#
# Note: you may need to restart the kernel to use updated packages.

# %%
df_image = pd.read_csv('image_predictions.tsv', delimiter = '\t')

# %%
df_image.sample(5)
# Out:
#                 tweet_id                                          jpg_url  \
# 219   670079681849372674  https://pbs.twimg.com/media/CUyZ6mVW4AI8YWZ.jpg
# 1070  716285507865542656  https://pbs.twimg.com/media/CfDB3aJXEAAEZNv.jpg
# 1452  776813020089548800  https://pbs.twimg.com/media/CsfLUDbXEAAu0VF.jpg
# 1699  816829038950027264  https://pbs.twimg.com/media/CvoBPWRWgAA4het.jpg
# 1821  834574053763584002  https://pbs.twimg.com/media/C5UAqgyXAAAbMWH.jpg
#
#       img_num                 p1   p1_conf  p1_dog                p2  \
# 219         1         mud_turtle  0.157477   False          terrapin
# 1070        1  Yorkshire_terrier  0.430420    True     silky_terrier
# 1452        1         toy_poodle  0.516610    True  miniature_poodle
# 1699        1         dishwasher  0.700466   False  golden_retriever
# 1821        1      toilet_tissue  0.262936   False  golden_retriever
#
#        p2_conf  p2_dog               p3   p3_conf  p3_dog
# ...

# %%
df_image.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2075 entries, 0 to 2074
# Data columns (total 12 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   tweet_id  2075 non-null   int64
#  1   jpg_url   2075 non-null   object
#  2   img_num   2075 non-null   int64
#  3   p1        2075 non-null   object
#  4   p1_conf   2075 non-null   float64
#  5   p1_dog    2075 non-null   bool
#  6   p2        2075 non-null   object
#  7   p2_conf   2075 non-null   float64
#  8   p2_dog    2075 non-null   bool
#  9   p3        2075 non-null   object
#  10  p3_conf   2075 non-null   float64
#  11  p3_dog    2075 non-null   bool
# dtypes: bool(3), float64(3), int64(2), object(4)
# memory usage: 152.1+ KB

# %%
df_twit = pd.read_csv('twitter-archive-enhanced-2.csv')

# %%
df_twit.sample(5)
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 447   819015331746349057                    NaN                  NaN
# 1240  712085617388212225                    NaN                  NaN
# 1788  677557565589463040                    NaN                  NaN
# 563   802572683846291456                    NaN                  NaN
# 1226  713919462244790272                    NaN                  NaN
#
#                       timestamp  \
# 447   2017-01-11 02:57:26 +0000
# 1240  2016-03-22 01:16:55 +0000
# 1788  2015-12-17 18:34:46 +0000
# 563   2016-11-26 18:00:13 +0000
# 1226  2016-03-27 02:43:58 +0000
#
#                                                  source  \
# 447   <a href="http://twitter.com/download/iphone" r...
# 1240  <a href="http://twitter.com/download/iphone" r...
# 1788  <a href="http://twitter.com/download/iphone" r...
# 563   <a href="http://twitter.com/download/iphone" r...
# 1226  <a href="http://twitter.com/download/iphone" r...
#
# ...

# %%
df_twit.columns
# Out:
# Index(['tweet_id', 'in_reply_to_status_id', 'in_reply_to_user_id', 'timestamp',
#        'source', 'text', 'retweeted_status_id', 'retweeted_status_user_id',
#        'retweeted_status_timestamp', 'expanded_urls', 'rating_numerator',
#        'rating_denominator', 'name', 'doggo', 'floofer', 'pupper', 'puppo'],
#       dtype='object')

# %%
df_twit[df_twit.rating_denominator == df_twit.rating_denominator.max() ]
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 1120  731156023742988288                    NaN                  NaN
#
#                       timestamp  \
# 1120  2016-05-13 16:15:54 +0000
#
#                                                  source  \
# 1120  <a href="http://twitter.com/download/iphone" r...
#
#                                                    text  retweeted_status_id  \
# 1120  Say hello to this unbelievably well behaved sq...                  NaN
#
#       retweeted_status_user_id retweeted_status_timestamp  \
# 1120                       NaN                        NaN
#
#                                           expanded_urls  rating_numerator  \
# 1120  https://twitter.com/dog_rates/status/731156023...               204
#
#       rating_denominator  name doggo floofer pupper puppo
# 1120                 170  this  None    None   None  None

# %%
df_twit[df_twit.rating_denominator != 10 ]['text']
# Out:
# 313      @jonnysun @Lin_Manuel ok jomny I know you're excited but 960/00 isn't a valid rating, 13/10 is tho
# 342                                                                @docmisterio account started on 11/15/15
# 433     The floofs have been released I repeat the floofs have been released. 84/70 https://t.co/NIYC820tmd
# 516     Meet Sam. She smiles 24/7 &amp; secretly aspires to be a reindeer. \nKeep Sam smiling by clickin...
# 784     RT @dog_rates: After so many requests, this is Bretagne. She was the last surviving 9/11 search ...
# 902                          Why does this never happen at my front door... 165/150 https://t.co/HmwrdfEfUE
# 1068    After so many requests, this is Bretagne. She was the last surviving 9/11 search dog, and our se...
# 1120    Say hello to this unbelievably well behaved squad of doggos. 204/170 would try to pet all at onc...
# 1165                                       Happy 4/20 from the squad! 13/10 for all https://t.co/eV1diwds8a
# ...

# %%
df_twit[df_twit.rating_denominator == df_twit.rating_denominator.min() ]
# Out:
#                tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 313  835246439529840640           8.352460e+17           26259576.0
#
#                      timestamp  \
# 313  2017-02-24 21:54:03 +0000
#
#                                                 source  \
# 313  <a href="http://twitter.com/download/iphone" r...
#
#                                                   text  retweeted_status_id  \
# 313  @jonnysun @Lin_Manuel ok jomny I know you're e...                  NaN
#
#      retweeted_status_user_id retweeted_status_timestamp expanded_urls  \
# 313                       NaN                        NaN           NaN
#
#      rating_numerator  rating_denominator  name doggo floofer pupper puppo
# 313               960                   0  None  None    None   None  None

# %%
df_twit[df_twit.rating_numerator == df_twit.rating_numerator.min() ]
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 315   835152434251116546                    NaN                  NaN
# 1016  746906459439529985           7.468859e+17         4.196984e+09
#
#                       timestamp  \
# 315   2017-02-24 15:40:31 +0000
# 1016  2016-06-26 03:22:31 +0000
#
#                                                  source  \
# 315   <a href="http://twitter.com/download/iphone" r...
# 1016  <a href="http://twitter.com/download/iphone" r...
#
#                                                    text  retweeted_status_id  \
# 315   When you're so blinded by your systematic plag...                  NaN
# 1016  PUPDATE: can't see any. Even if I could, I cou...                  NaN
#
#       retweeted_status_user_id retweeted_status_timestamp  \
# 315                        NaN                        NaN
# 1016                       NaN                        NaN
#
# ...

# %%
df_twit[df_twit.rating_numerator == df_twit.rating_numerator.max() ]
# Out:
#                tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 979  749981277374128128                    NaN                  NaN
#
#                      timestamp  \
# 979  2016-07-04 15:00:45 +0000
#
#                                                 source  \
# 979  <a href="https://about.twitter.com/products/tw...
#
#                                                   text  retweeted_status_id  \
# 979  This is Atticus. He's quite simply America af....                  NaN
#
#      retweeted_status_user_id retweeted_status_timestamp  \
# 979                       NaN                        NaN
#
#                                          expanded_urls  rating_numerator  \
# 979  https://twitter.com/dog_rates/status/749981277...              1776
#
#      rating_denominator     name doggo floofer pupper puppo
# 979                  10  Atticus  None    None   None  None

# %%
df_twit.puppo.unique()
# Out:
# array(['None', 'puppo'], dtype=object)

# %%
df_twit.name.unique()
# Out:
# array(['Phineas', 'Tilly', 'Archie', 'Darla', 'Franklin', 'None', 'Jax',
#        'Zoey', 'Cassie', 'Koda', 'Bruno', 'Ted', 'Stuart', 'Oliver',
#        'Jim', 'Zeke', 'Ralphus', 'Canela', 'Gerald', 'Jeffrey', 'such',
#        'Maya', 'Mingus', 'Derek', 'Roscoe', 'Waffles', 'Jimbo', 'Maisey',
#        'Lilly', 'Earl', 'Lola', 'Kevin', 'Yogi', 'Noah', 'Bella',
#        'Grizzwald', 'Rusty', 'Gus', 'Stanley', 'Alfy', 'Koko', 'Rey',
#        'Gary', 'a', 'Elliot', 'Louis', 'Jesse', 'Romeo', 'Bailey',
#        'Duddles', 'Jack', 'Emmy', 'Steven', 'Beau', 'Snoopy', 'Shadow',
#        'Terrance', 'Aja', 'Penny', 'Dante', 'Nelly', 'Ginger', 'Benedict',
#        'Venti', 'Goose', 'Nugget', 'Cash', 'Coco', 'Jed', 'Sebastian',
#        'Walter', 'Sierra', 'Monkey', 'Harry', 'Kody', 'Lassie', 'Rover',
#        'Napolean', 'Dawn', 'Boomer', 'Cody', 'Rumble', 'Clifford',
#        'quite', 'Dewey', 'Scout', 'Gizmo', 'Cooper', 'Harold', 'Shikha',
# ...

# %%
df_twit.tweet_id.duplicated().sum()
# Out:
# 0

# %%
df_twit.tweet_id.duplicated().sum()

# %%
df = pd.read_csv('twitter-archive-enhanced-2.csv')

# %%
df.sample(3)
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 2352  666044226329800704                    NaN                  NaN
# 127   867900495410671616                    NaN                  NaN
# 847   766078092750233600                    NaN                  NaN
#
#                       timestamp  \
# 2352  2015-11-16 00:04:52 +0000
# 127   2017-05-26 00:29:37 +0000
# 847   2016-08-18 01:03:45 +0000
#
#                                                  source  \
# 2352  <a href="http://twitter.com/download/iphone" r...
# 127   <a href="http://twitter.com/download/iphone" r...
# 847   <a href="http://twitter.com/download/iphone" r...
#
#                                                    text  retweeted_status_id  \
# 2352  This is a purebred Piers Morgan. Loves to Netf...                  NaN
# 127   Unbelievable. We only rate dogs. Please don't ...                  NaN
# 847   RT @dog_rates: This is Colby. He's currently r...         7.258423e+17
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2356 entries, 0 to 2355
# Data columns (total 17 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   tweet_id                    2356 non-null   int64
#  1   in_reply_to_status_id       78 non-null     float64
#  2   in_reply_to_user_id         78 non-null     float64
#  3   timestamp                   2356 non-null   object
#  4   source                      2356 non-null   object
#  5   text                        2356 non-null   object
#  6   retweeted_status_id         181 non-null    float64
#  7   retweeted_status_user_id    181 non-null    float64
#  8   retweeted_status_timestamp  181 non-null    object
#  9   expanded_urls               2297 non-null   object
#  10  rating_numerator            2356 non-null   int64
#  11  rating_denominator          2356 non-null   int64
#  12  name                        2356 non-null   object
# ...

# %%
df.describe()
# Out:
#            tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# count  2.356000e+03           7.800000e+01         7.800000e+01
# mean   7.427716e+17           7.455079e+17         2.014171e+16
# std    6.856705e+16           7.582492e+16         1.252797e+17
# min    6.660209e+17           6.658147e+17         1.185634e+07
# 25%    6.783989e+17           6.757419e+17         3.086374e+08
# 50%    7.196279e+17           7.038708e+17         4.196984e+09
# 75%    7.993373e+17           8.257804e+17         4.196984e+09
# max    8.924206e+17           8.862664e+17         8.405479e+17
#
#        retweeted_status_id  retweeted_status_user_id  rating_numerator  \
# count         1.810000e+02              1.810000e+02       2356.000000
# mean          7.720400e+17              1.241698e+16         13.126486
# std           6.236928e+16              9.599254e+16         45.876648
# min           6.661041e+17              7.832140e+05          0.000000
# ...

# %%
df_count = pd.read_csv('twitter_count.csv')

# %%
df_count.sample(10)
# Out:
#                 tweet_id  retweet_count  favorite_count
# 20    887705289381826560           4801           27881
# 1827  675707330206547968            646            1884
# 2189  668544745690562560            212             481
# 1226  711008018775851008            591            2919
# 2134  669571471778410496            943            1491
# 621   793256262322548741           8323           19987
# 2002  671874878652489728            516            1183
# 434   818646164899774465          20793               0
# 604   796080075804475393           2303            8460
# 922   752568224206688256           2231            5401

# %%
df_count.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2331 entries, 0 to 2330
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   tweet_id        2331 non-null   int64
#  1   retweet_count   2331 non-null   int64
#  2   favorite_count  2331 non-null   int64
# dtypes: int64(3)
# memory usage: 54.8 KB

# %%
df_image = pd.read_csv('image_predictions.tsv', delimiter = '\t')

# %%
df_image.sample(100)
# Out:
#                 tweet_id  \
# 96    667724302356258817
# 2052  887517139158093824
# 162   668955713004314625
# 1641  807106840509214720
# 1174  737322739594330112
# ...                  ...
# 1931  859074603037188101
# 1926  857746408056729600
# 1199  740711788199743490
# 1938  860524505164394496
# 507   676089483918516224
#
#                                                                                       jpg_url  \
# 96                                            https://pbs.twimg.com/media/CUQ7tv3W4AA3KlI.jpg
# 2052  https://pbs.twimg.com/ext_tw_video_thumb/887517108413886465/pu/img/WanJKwssZj4VJvL9.jpg
# 162                                           https://pbs.twimg.com/media/CUibq3uVAAAup_O.jpg
# 1641  https://pbs.twimg.com/ext_tw_video_thumb/807106774843039744/pu/img/8XZg1xW35Xp2J6JW.jpg
# 1174                                          https://pbs.twimg.com/media/Cjt_Hm6WsAAjkPG.jpg
# ...

# %%
df_image.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2075 entries, 0 to 2074
# Data columns (total 12 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   tweet_id  2075 non-null   int64
#  1   jpg_url   2075 non-null   object
#  2   img_num   2075 non-null   int64
#  3   p1        2075 non-null   object
#  4   p1_conf   2075 non-null   float64
#  5   p1_dog    2075 non-null   bool
#  6   p2        2075 non-null   object
#  7   p2_conf   2075 non-null   float64
#  8   p2_dog    2075 non-null   bool
#  9   p3        2075 non-null   object
#  10  p3_conf   2075 non-null   float64
#  11  p3_dog    2075 non-null   bool
# dtypes: bool(3), float64(3), int64(2), object(4)
# memory usage: 152.1+ KB
